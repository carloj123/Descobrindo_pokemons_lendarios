# %%
import pandas as pd
import numpy as np

# %%
 df3 = pd.read_csv('ks-projects-201801.csv', encoding = "utf-8",)

# %%
print(df3.head())
df3["state"].unique()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# ...

# %%
import matplotlib.pyplot as plt  
import matplotlib as mpl

# %%
df3["satatus"] = df3["state"].replace(['canceled','suspended'],'failed')
df3 = df3[df3["state"] !='live']
df3 = df3[df3["state"] !='undefined']

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 372300 entries, 0 to 378660
# Data columns (total 16 columns):
# ID                  372300 non-null int64
# name                372296 non-null object
# category            372300 non-null object
# main_category       372300 non-null object
# currency            372300 non-null object
# deadline            372300 non-null object
# goal                372300 non-null float64
# launched            372300 non-null object
# pledged             372300 non-null float64
# state               372300 non-null object
# backers             372300 non-null int64
# country             372300 non-null object
# usd pledged         372066 non-null float64
# usd_pledged_real    372300 non-null float64
# usd_goal_real       372300 non-null float64
# satatus             372300 non-null object
# dtypes: float64(5), int64(2), object(9)
# memory usage: 35.5+ MB

# %%
df3["launched"]= [i.split(" ")[0] for i in df3["launched"]]

# %%
df3["launched"]
# Out:
# 0         2015-08-11
# 1         2017-09-02
# 2         2013-01-12
# 3         2012-03-17
# 4         2015-07-04
# 5         2016-02-26
# 6         2014-12-01
# 7         2016-02-01
# 8         2014-04-24
# 9         2014-07-11
# 10        2013-09-09
# 11        2013-03-09
# 12        2014-09-02
# 13        2016-02-09
# 14        2017-04-05
# 15        2015-01-29
# 16        2014-10-09
# 17        2015-04-10
# 18        2012-08-02
# 19        2012-05-03
# 20        2013-11-25
# 21        2017-08-08
# 22        2014-05-16
# 23        2015-01-26
# 24        2014-10-23
# 25        2010-12-07
# 26        2015-12-06
# 27        2014-11-14
# 28        2015-12-29
# 29        2017-04-03
#              ...
# 378631    2014-09-03
# 378632    2014-05-06
# 378633    2014-11-13
# 378634    2010-11-08
# 378635    2015-08-25
# 378636    2014-11-17
# 378637    2017-08-29
# 378638    2014-07-15
# 378639    2015-11-03
# 378640    2014-08-08
# 378641    2015-07-06
# 378642    2017-10-04
# ...

# %%
df3["deadline"] = pd.to_datetime(df3["deadline"])
df3["launched"] = pd.to_datetime(df3["launched"])

# %%
df3["duration_days"] = (df3["deadline"] - df3["launched"]).dt.days

# %%
df3 = df3.drop(["ID","name","currency"],axis = 1)

# %%
df3.head(50)
# Out:
#           category main_category   deadline      goal   launched   pledged  \
# 0           Poetry    Publishing 2015-10-09    1000.0 2015-08-11      0.00
# 1   Narrative Film  Film & Video 2017-11-01   30000.0 2017-09-02   2421.00
# 2   Narrative Film  Film & Video 2013-02-26   45000.0 2013-01-12    220.00
# 3            Music         Music 2012-04-16    5000.0 2012-03-17      1.00
# 4     Film & Video  Film & Video 2015-08-29   19500.0 2015-07-04   1283.00
# 5      Restaurants          Food 2016-04-01   50000.0 2016-02-26  52375.00
# 6             Food          Food 2014-12-21    1000.0 2014-12-01   1205.00
# 7           Drinks          Food 2016-03-17   25000.0 2016-02-01    453.00
# 8   Product Design        Design 2014-05-29  125000.0 2014-04-24   8233.00
# 9      Documentary  Film & Video 2014-08-10   65000.0 2014-07-11   6240.57
# 10      Nonfiction    Publishing 2013-10-09    2500.0 2013-09-09      0.00
# ...

# %%
df3 = df3[df3["state"] != "undefined"]

df3 = df3[df3["state"] != "live"]

df3.head()
# Out:
#          category main_category   deadline     goal   launched  pledged  \
# 0          Poetry    Publishing 2015-10-09   1000.0 2015-08-11      0.0
# 1  Narrative Film  Film & Video 2017-11-01  30000.0 2017-09-02   2421.0
# 2  Narrative Film  Film & Video 2013-02-26  45000.0 2013-01-12    220.0
# 3           Music         Music 2012-04-16   5000.0 2012-03-17      1.0
# 4    Film & Video  Film & Video 2015-08-29  19500.0 2015-07-04   1283.0
#
#       state  backers country  usd pledged  usd_pledged_real  usd_goal_real  \
# 0    failed        0      GB          0.0               0.0        1533.95
# 1    failed       15      US        100.0            2421.0       30000.00
# 2    failed        3      US        220.0             220.0       45000.00
# 3    failed        1      US          1.0               1.0        5000.00
# 4  canceled       14      US       1283.0            1283.0       19500.00
#
#   satatus  duration_days
# 0  failed             59
# 1  failed             60
# ...

# %%
df3 = df3.drop("pledged", axis = 1)
df3 = df3.drop("usd pledged", axis = 1)

# %%
df3.head()
# Out:
#          category main_category   deadline     goal   launched     state  \
# 0          Poetry    Publishing 2015-10-09   1000.0 2015-08-11    failed
# 1  Narrative Film  Film & Video 2017-11-01  30000.0 2017-09-02    failed
# 2  Narrative Film  Film & Video 2013-02-26  45000.0 2013-01-12    failed
# 3           Music         Music 2012-04-16   5000.0 2012-03-17    failed
# 4    Film & Video  Film & Video 2015-08-29  19500.0 2015-07-04  canceled
#
#    backers country  usd_pledged_real  usd_goal_real satatus  duration_days
# 0        0      GB               0.0        1533.95  failed             59
# 1       15      US            2421.0       30000.00  failed             60
# 2        3      US             220.0       45000.00  failed             45
# 3        1      US               1.0        5000.00  failed             30
# 4       14      US            1283.0       19500.00  failed             56

# %%
df3 = df3.drop("goal", axis = 1)

# %%
df3.head()
# Out:
#          category main_category   deadline   launched     state  backers  \
# 0          Poetry    Publishing 2015-10-09 2015-08-11    failed        0
# 1  Narrative Film  Film & Video 2017-11-01 2017-09-02    failed       15
# 2  Narrative Film  Film & Video 2013-02-26 2013-01-12    failed        3
# 3           Music         Music 2012-04-16 2012-03-17    failed        1
# 4    Film & Video  Film & Video 2015-08-29 2015-07-04  canceled       14
#
#   country  usd_pledged_real  usd_goal_real satatus  duration_days
# 0      GB               0.0        1533.95  failed             59
# 1      US            2421.0       30000.00  failed             60
# 2      US             220.0       45000.00  failed             45
# 3      US               1.0        5000.00  failed             30
# 4      US            1283.0       19500.00  failed             56

# %%
import calendar
df3["deadline"] =[ calendar.month_name[i.month] for i in df3["deadline"]]

# %%
df3["launched"] =[ calendar.month_name[i.month] for i in df3["launched"]]

# %%
df3.head()
# Out:
#          category main_category  deadline   launched     state  backers  \
# 0          Poetry    Publishing   October     August    failed        0
# 1  Narrative Film  Film & Video  November  September    failed       15
# 2  Narrative Film  Film & Video  February    January    failed        3
# 3           Music         Music     April      March    failed        1
# 4    Film & Video  Film & Video    August       July  canceled       14
#
#   country  usd_pledged_real  usd_goal_real satatus  duration_days
# 0      GB               0.0        1533.95  failed             59
# 1      US            2421.0       30000.00  failed             60
# 2      US             220.0       45000.00  failed             45
# 3      US               1.0        5000.00  failed             30
# 4      US            1283.0       19500.00  failed             56

# %%
print(df3.country.unique())
# Out:
# ['GB' 'US' 'CA' 'AU' 'NO' 'IT' 'DE' 'IE' 'MX' 'ES' 'SE' 'FR' 'NL' 'NZ'
#  'CH' 'AT' 'DK' 'BE' 'HK' 'LU' 'SG' 'N,0"' 'JP']

# %%
datasets = [df3[df3['country'] == i] for i in df3.country.unique()]

# %%
for i in datasets:
    print(i)
    print("/n")
# Out:
#                 category main_category   deadline   launched       state  \
# 0                 Poetry    Publishing    October     August      failed
# 14        Tabletop Games         Games        May      April  successful
# 26                   DIY        Crafts    January   December      failed
# 28                Comics        Comics    January   December  successful
# 30           Food Trucks          Food      March      March      failed
# 67              Software    Technology       July       June      failed
# 69               Weaving        Crafts      April      March      failed
# 75        Product Design        Design     August       July      failed
# 80               Fashion       Fashion   February   December      failed
# 129         Film & Video  Film & Video      March      March      failed
# 131          Documentary  Film & Video      March    January  successful
# 141                Drama  Film & Video      March      March  successful
# ...

# %%
df3.to_csv("oura_merda.csv")

# %%
df3 = df3.dropna()

# %%
from sklearn import preprocessing
encoder = preprocessing.OrdinalEncoder()

# %%
encoder = preprocessing.OrdinalEncoder()
category_encoder = encoder.fit(pd.DataFrame(df3.category))

# %%
encoder = preprocessing.OrdinalEncoder()
main_category_encoder = encoder.fit(pd.DataFrame(df3.main_category))

# %%
encoder = preprocessing.OrdinalEncoder()
deadline_encoder = encoder.fit(pd.DataFrame(df3.deadline))

# %%
encoder = preprocessing.OrdinalEncoder()
launched_encoder = encoder.fit(pd.DataFrame(df3.launched))

# %%
encoder = preprocessing.OrdinalEncoder()
state_encoder = encoder.fit(pd.DataFrame(df3.state))

# %%
encoder = preprocessing.OrdinalEncoder()
country_encoder = encoder.fit(pd.DataFrame(df3.country))

# %%
df3_category_encoded = category_encoder.transform(pd.DataFrame(df3["category"]))

# %%
df3_main_category_encoded = main_category_encoder.transform(pd.DataFrame(df3["main_category"]))

# %%
df3_deadline_encoded = deadline_encoder.transform(pd.DataFrame(df3["deadline"]))

# %%
df3_launched_encoded = launched_encoder.transform(pd.DataFrame(df3["launched"]))

# %%
df3_state_encoded = state_encoder.transform(pd.DataFrame(df3["state"]))

# %%
df3_country_encoded = country_encoder.transform(pd.DataFrame(df3["country"]))

# %%
#df3_encoded=encoder.transform(df3)
#pd.DataFrame(pendins_fora.groupby('leadName').size())

# %%
dfr_encoded = pd.DataFrame(df3_category_encoded)

# %%
dfr_encoded.columns = ["category"]

# %%
dfr_encoded["main_category"] = df3_main_category_encoded

# %%
dfr_encoded["deadline"] = df3_deadline_encoded

# %%
dfr_encoded["launched"] = df3_launched_encoded

# %%
dfr_encoded["state"] = df3_state_encoded

# %%
dfr_encoded["backers"] = df3["backers"]

# %%
dfr_encoded["country"] = df3_country_encoded

# %%
#dfr_encoded["usd pledged"] = df3["usd pledged"]

# %%
dfr_encoded["usd_pledged_real"] = df3["usd_pledged_real"]

# %%
dfr_encoded["usd_goal_real"] = df3["usd_goal_real"]

# %%
dfr_encoded["duration_days"] = df3["duration_days"]

# %%
#df3_encode_db = pd.DataFrame(df3_encoded)

# %%
#df3_encode_db

# %%
import seaborn as sns
corr = dfr_encoded.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
dfr_encoded.to_csv("essa_merda.csv")

# %%
df3.head()
# Out:
#          category main_category  deadline   launched     state  backers  \
# 0          Poetry    Publishing   October     August    failed        0
# 1  Narrative Film  Film & Video  November  September    failed       15
# 2  Narrative Film  Film & Video  February    January    failed        3
# 3           Music         Music     April      March    failed        1
# 4    Film & Video  Film & Video    August       July  canceled       14
#
#   country  usd_pledged_real  usd_goal_real satatus  duration_days
# 0      GB               0.0        1533.95  failed             59
# 1      US            2421.0       30000.00  failed             60
# 2      US             220.0       45000.00  failed             45
# 3      US               1.0        5000.00  failed             30
# 4      US            1283.0       19500.00  failed             56

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier()

# %%
from sklearn.model_selection import train_test_split

# %%
X = dfr_encoded.drop("state",axis = 1)
y = dfr_encoded["state"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.metrics import classification_report

# %%
clf.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-86937c1966f0> in <module>
# ----> 1 clf.fit(X_train,y_train)
#
# c:\users\carlolaitano\documents\facul\sgbd\venv\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     814             sample_weight=sample_weight,
#     815             check_input=check_input,
# --> 816             X_idx_sorted=X_idx_sorted)
#     817         return self
#     818
#
# c:\users\carlolaitano\documents\facul\sgbd\venv\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     128         random_state = check_random_state(self.random_state)
#     129         if check_input:
# --> 130             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     131             y = check_array(y, ensure_2d=False, dtype=None)
# ...

# %%
y_train.info()
